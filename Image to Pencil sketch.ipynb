# %%
#Importing Required Libraries
import cv2
from cv2_plt_imshow import cv2_plt_imshow
import matplotlib.pyplot as plt

# %%
pip install cv2_plt_imshow
# Out:
# Collecting cv2_plt_imshow
#   Downloading cv2_plt_imshow-0.0.1-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from cv2_plt_imshow) (3.4.3)
# Requirement already satisfied: opencv-python>=4.2.0.34 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from cv2_plt_imshow) (4.5.5.62)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from matplotlib>=3.2.2->cv2_plt_imshow) (2.8.2)
# Requirement already satisfied: six in c:\users\mamtesh bagade\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.2->cv2_plt_imshow) (1.16.0)
# Installing collected packages: cv2-plt-imshow
# Successfully installed cv2-plt-imshow-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing real Image
image=cv2.imread("lgm.png")
cv2_plt_imshow(image)

# %%
#Converting Image into Grey Scale Image
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
cv2_plt_imshow(grey_image)

# %%
#Inverting the grey scale image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_plt_imshow(inverted_image)

# %%
#Image Smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_plt_imshow(image_smoothing)

# %%
#Pencil sketch
def pencil_sketch(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_plt_imshow(pencil_sketch)
